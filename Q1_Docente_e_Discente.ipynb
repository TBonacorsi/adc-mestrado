# %% [markdown]
# <a href="https://colab.research.google.com/github/TBonacorsi/adc-mestrado/blob/main/Q1_Docente_e_Discente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


df = pd.read_csv('/content/Q1-Doc.xlsx - MapaCorrelação.csv')
corr =  df.corr()

# Create a mask
mask = np.triu(np.ones_like(corr, dtype=bool))

df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'coolwarm', center=0, vmin=-1, vmax=1, linewidth = 0.5, mask=mask, annot = True)
# Out:
# <ipython-input-5-c0165b634fe4>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr =  df.corr()
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv('/content/Q1-Doc.xlsx - MapaCorrelação (2).csv')
corr =  df.corr()

# Create a mask
mask = np.triu(np.ones_like(corr, dtype=bool))

df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, mask=mask, annot = True)
# Out:
# <ipython-input-4-80bf95c18ebe>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr =  df.corr()
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Doc.xlsx - G-Dificuldades (1).csv')
color = ('DarkBlue', 'Teal', 'DodgerBlue')

ax = df[['Dificuldade', 'Tecnologia', 'Corpo', 'Organizacionais']].plot(figsize=(12, 5), kind = 'barh', color= color)
ax.set_yticklabels(df['Dificuldade'])
plt.xlabel('\nPorcentagem Docentes (%) com tal dificuldade')
plt.xlim(0, 100)
plt.title('Dificuldades observadas pelos docentes durante o ERE')

# para add rótulo = ax.bar_label(ax, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Dificuldades observadas pelos docentes durante o ERE')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Q1-Doc.xlsx - AlteraçõesGeraisCorr.csv')
df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Doc.xlsx - AlteraçõesGeraisSim (2).csv')

ax = df[['Alterações Gerais', 'g1%']].plot(figsize=(12, 5), kind = 'barh', color= 'DarkCyan')
ax.set_yticklabels(df['Alterações Gerais'])
plt.xlabel('\nPorcentagem de docentes (%) que alteraram tal item')
plt.legend()
ax.get_legend().remove()
plt.title('Alterações realizadas durante o ERE')

# para add rótulo = ax.bar_label(df, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Alterações realizadas durante o ERE')

# %%
#Importando as bibliotecas necessárias
import pandas as pd;
import numpy as np;
import seaborn as sns; sns.set();
import matplotlib.pyplot as plt;
import plotly.express as px;

##Importando o data set
df= pd.read_csv('Q1-Dis.xlsx - RecitaisXSemestre--TEMPO (1).csv')
df.head()

fig  = px.scatter(df, x = 'Semestre', y = 'Quantidade Recitais ', size = "RepetePlus",
                  hover_name = "Tempo", color='Tempo')
# isso aqui sai pra ficar com as bolhas fig.update_traces(marker = dict(size = 'Repete', line=dict(width = 2)), selector = dict(mode = 'markers'))
fig.update_layout(title = 'Comparativo das apresentações públicas por semestre (n=43)')
fig.update_xaxes(title = 'Semestre')
fig.update_yaxes(title = 'Quantidade de Recitais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Importando as bibliotecas necessárias
import pandas as pd;
import numpy as np;
import seaborn as sns; sns.set();
import matplotlib.pyplot as plt;
import plotly.express as px;

##Importando o data set
df= pd.read_csv('/Q1-Dis.xlsx - RecitaisxSemestre (2).csv')
df.head()

fig  = px.scatter(df, x = 'Semestre', y = 'Quantidade RecitaisPd', width = 800, color='Instrumento')
fig.update_traces(marker = dict(size = 12, line=dict(width = 2)), selector = dict(mode = 'markers'))
fig.update_layout(title = 'Semestre da graduação X Quantidade de Recitais - Durante a pandemia')
fig.update_xaxes(title = 'Semestre')
fig.update_yaxes(title = 'Quantidade de Recitais')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Q1-Doc.xlsx - TecCorr.csv')
df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
plt.title('Correlação entre as tecnologias digitais')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8d21b3d22812> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 df = pd.read_csv('/content/Q1-Doc.xlsx - TecCorr.csv')
#       6 df_2 = df.select_dtypes(exclude='object')
#       7
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Doc.xlsx - TecSim (1).csv')


ax = df[['Tecnologias', 'g1%']].plot(figsize=(12, 5), kind = 'barh', color= 'DarkCyan')
ax.set_yticklabels(df['Tecnologias'])
plt.xlabel('\nPorcentagem (%) de docentes aderentes')
plt.legend()
ax.get_legend().remove()
plt.title('Aderencia docente aos softwares')

# para add rótulo = ax.bar_label(df, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Aderencia docente aos softwares')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Dis.xlsx - TecSim (1).csv')


ax = df[['Tecnologias', 'g1%']].plot(figsize=(12, 5), kind = 'barh', color= 'DarkCyan')
ax.set_yticklabels(df['Tecnologias'])
plt.xlabel('\nPorcentagem (%) de discentes aderentes')
plt.legend()
ax.get_legend().remove()
plt.xlim(0, 100)
plt.title('Aderência discente aos softwares')

# para add rótulo = ax.bar_label(df, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Aderencia discente aos softwares')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Q1-Dis.xlsx - DificuldadeCorr.csv')
df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Dis.xlsx - DificuldadesSim (1).csv')
color = ('DarkBlue', 'Teal', 'DodgerBlue')

ax = df[['Dificuldade', 'Tecnologia', 'Corpo', 'Organizacionais']].plot(figsize=(12, 5), kind = 'barh', color= color)
ax.set_yticklabels(df['Dificuldade'])
plt.xlabel('\n(%) porcentagem de discentes com tal dificuldade')
plt.xlim(0, 100)
plt.title('Dificuldades observadas pelos discentes durante o ERE')

# para add rótulo = ax.bar_label(ax, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Dificuldades observadas pelos discentes durante o ERE')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Q1-Dis.xlsx - TecCorr.csv')
df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Dis.xlsx - TecSim.csv')


ax = df[['Tecnologias', 'g1%']].plot(figsize=(12, 5), kind = 'barh', color= 'DarkCyan')
ax.set_yticklabels(df['Tecnologias'])
plt.xlabel('\nPorcentagem Discentes (%)')
plt.legend()
ax.get_legend().remove()
plt.title('Tecnologias digitais usadas por discentes')

# para add rótulo = ax.bar_label(df, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Tecnologias digitais usadas por discentes')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Dis.xlsx - RotinaSim (1).csv')


ax = df[['Rotina', 'x%']].plot(figsize=(12, 5), kind = 'barh', color= 'DarkCyan')
ax.set_yticklabels(df['Rotina'])
plt.xlabel('\nPorcentagem de discentes (%) que mantiveram essa rotina')
plt.legend()
ax.get_legend().remove()
plt.title('Rotina de estudo - momentos')

# para add rótulo = ax.bar_label(df, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Rotina de estudo - momentos')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Q1-Dis.xlsx - EvoluçãoCorr.csv')
df_2 = df.select_dtypes(exclude='object')

fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(df_2.corr(), cmap = 'Blues', linewidth = 0.5, annot = True)
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Dis.xlsx - EvoluçãoSim.csv')


ax = df[['Evolução da Performance', 'x%']].plot(figsize=(12, 5), kind = 'barh', color= 'DarkCyan')
ax.set_yticklabels(df['Evolução da Performance'])
plt.xlabel('\nPorcentagem Discentes (%)')
plt.legend()
ax.get_legend().remove()
plt.title('Percepção discente sobre sua evolução na Performance')

# para add rótulo = ax.bar_label(df, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Percepção discente sobre sua evolução na Performance')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/Q1-Dis.xlsx - VideoComp2x (1).csv')
color = ('DarkBlue', 'DarkCyan')

ax = df[['Usuários', 'Discentes', 'Docentes']].plot(figsize=(12, 5), kind = 'barh', color= color)
ax.set_yticklabels(df['Usuários'])
plt.xlabel('\nPorcentagem de adesão pelo grupo (%)')
plt.title('Serviços de Videoconferência')

# para add rótulo = ax.bar_label(ax, fmt='{:.0f}%', size=10, label_type="edge")
# Out:
# Text(0.5, 1.0, 'Serviços de Videoconferência')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Valores do Gráfico #
y = np.array([12, 8, 10])

# Itens do Gráfico #
mylabels = ['Concomitante', 'Distintos', 'Outros']



# Monta o Gráfico e depois o mostra na tela #
colors = ['CadetBlue', 'Teal', 'DodgerBlue']

plt.pie(y, labels=mylabels, autopct='%1.1f%%', colors = colors, shadow=True)
plt.legend(loc=9,
          bbox_to_anchor=(1.2,.75),
          fontsize=14)
plt.title("Relação Repertório x Técnica")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Valores do Gráfico #
y = np.array([9, 15, 6])

# Itens do Gráfico #
mylabels = ['Viola', 'Violino', 'Violino/Viola']



# Monta o Gráfico e depois o mostra na tela #
colors = ['CadetBlue', 'Teal', 'DodgerBlue']

plt.pie(y, labels=mylabels, autopct='%1.1f%%', colors = colors, shadow=True)
plt.legend(loc=9,
          bbox_to_anchor=(1.2,.75),
          fontsize=10)
plt.title("Grupo docente consultado (n=30)")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Valores do Gráfico #
y = np.array([20, 23])

# Itens do Gráfico #
mylabels = ['Viola', 'Violino']



# Monta o Gráfico e depois o mostra na tela #
colors = ['CadetBlue', 'Teal',]

plt.pie(y, labels=mylabels, autopct='%1.1f%%', colors = colors, shadow=True)
plt.legend(loc=9,
          bbox_to_anchor=(1.2,.75),
          fontsize=10)
plt.title("Grupo discente consultado (n=43)")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wordcloud import ImageColorGenerator
import sys
import io
import os
os.chdir(sys.path[0])

# read text
with io.open('/content/Programas_de_curso_Total.txt','r', encoding="latin_1") as texto:
  texto = texto.read()
stopwords = STOPWORDS


#endereço do local da sua imagem e fonte tipográfica
mask= np.array(Image.open('MapaBrasil.jpg'))
mask_colors = ImageColorGenerator(mask)


#Gerando a WC
wc = WordCloud(mask=mask, background_color="White",
               max_words=30, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0])

wc.generate(texto)

# store to file
plt.figure(figsize = (15, 10)) # tamanho do gráfico
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import pandas as pd
import matplotlib.pyplot as plt

#criar dataframe
df = pd.read_txt('/content/Programas_de_curso_Total.txt')

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wordcloud import ImageColorGenerator
import sys
import io
import os
os.chdir(sys.path[0])


with io.open('/content/Programas_de_curso_Total.txt','r', encoding="latin_1") as texto:
  texto = texto.read().lower()
stopwords = STOPWORDS

texto_sem_pontuacao = ' '
for c in texto:
    if c.isalpha() or c == ' ':
        texto_sem_pontuacao += c

palavras = texto_sem_pontuacao.split()

frequencia_palavras = {}
for palavra in palavras:
    if palavra not in frequencia_palavras:
        frequencia_palavras[palavra] = 0

    frequencia_palavras[palavra] += 1

frequencia_palavras = Counter(palavras)

rotulos, valores = zip(*frequencia_palavras.most_common(8))
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.figure(figsize = (30, 12)) # tamanho do gráfico
splot= plt.bar(rotulos, valores, color= 'DarkCyan')
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=2000,
                    hspace=0.8)
plt.title('Palavras mais frequentes nas ementas de VA/VL', fontsize=20)
plt.bar_label(splot.containers[0])
# possibilidade 2 caso a 1 n funcione ax.bar_label(grafico_1_unidade, fmt="%.01f", size=10, label_type="edge")
plt.ylim(0, 120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-de273fa909ae> in <cell line: 12>()
#      10
#      11
# ---> 12 with io.open('/content/Programas_de_curso_Total.txt','r', encoding="latin_1") as texto:
#      13   texto = texto.read().lower()
#      14 stopwords = STOPWORDS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Programas_de_curso_Total.txt'

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wordcloud import ImageColorGenerator
import sys
import io
import os
os.chdir(sys.path[0])

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wordcloud import ImageColorGenerator
import sys
import io
import os
os.chdir(sys.path[0])


with io.open('/content/Transcricoes_REDE.txt','r', encoding="latin_1") as texto:
  texto = texto.read().lower()
stopwords = STOPWORDS

texto_sem_pontuacao = ' '
for c in texto:
    if c.isalpha() or c == ' ':
        texto_sem_pontuacao += c

palavras = texto_sem_pontuacao.split()

frequencia_palavras = {}
for palavra in palavras:
    if palavra not in frequencia_palavras:
        frequencia_palavras[palavra] = 0

    frequencia_palavras[palavra] += 1

frequencia_palavras = Counter(palavras)

rotulos, valores = zip(*frequencia_palavras.most_common(10))
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.figure(figsize = (30, 12)) # tamanho do gráfico
splot= plt.bar(rotulos, valores, color= 'DarkCyan')
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=2000,
                    hspace=0.8)
plt.title('Palavras mais frequentes nas ementas de VA/VL', fontsize=20)
plt.bar_label(splot.containers[0])
# possibilidade 2 caso a 1 n funcione ax.bar_label(grafico_1_unidade, fmt="%.01f", size=10, label_type="edge")
plt.ylim(0, 120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-83724cb1e1cf> in <cell line: 44>()
#      42                     hspace=0.8)
#      43 plt.title('Palavras mais frequentes nas ementas de VA/VL', fontsize=20)
# ---> 44 plt.bar_label(splot.containers[0])
#      45 # possibilidade 2 caso a 1 n funcione ax.bar_label(grafico_1_unidade, fmt="%.01f", size=10, label_type="edge")
#      46 plt.ylim(0, 120)
#
# AttributeError: 'BarContainer' object has no attribute 'containers'

# %%
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wordcloud import ImageColorGenerator
import sys
import io
import os
os.chdir(sys.path[0])

# read text
with io.open('/content/Transcricoes_REDE.txt','r', encoding="latin_1") as texto:
  texto = texto.read()
stopwords = STOPWORDS, ['e', 'uma', 'que', 'eu']


#endereço do local da sua imagem e fonte tipográfica
#mask= np.array(Image.open('MapaBrasil.jpg'))
#mask_colors = ImageColorGenerator(mask)


#Gerando a WC
wc = WordCloud(background_color="White",
               max_words=30, max_font_size=100,
               random_state=42, width=250,
               height=250)

wc.generate(texto)

# store to file
plt.figure(figsize = (15, 10)) # tamanho do gráfico
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import STOPWORDS

import io

with io.open('/content/Programas_de_curso_Total.txt','r', encoding="latin_1") as texto:
  texto = texto.read().lower()
stopwords = STOPWORDS

texto_sem_pontuacao = ' '
for c in texto:
    if c.isalpha() or c == ' ':
        texto_sem_pontuacao += c

palavras = texto_sem_pontuacao.split()

frequencia_palavras = {}
for palavra in palavras:
    if palavra not in frequencia_palavras:
        frequencia_palavras[palavra] = 0

    frequencia_palavras[palavra] += 1

frequencia_palavras = Counter(palavras)

rotulos, valores = zip(*frequencia_palavras.most_common(8))

plt.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d9c7b2082f05> in <cell line: 29>()
#      27 rotulos, valores = zip(*frequencia_palavras.most_common(8))
#      28
# ---> 29 plt.read()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'read'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from wordcloud import STOPWORDS

import io

with io.open('/content/projeto.txt','r', encoding="latin_1") as texto:
  texto = texto.read().lower()
stopwords = STOPWORDS

texto_sem_pontuacao = ' '
for c in texto:
    if c.isalpha() or c == ' ':
        texto_sem_pontuacao += c

palavras = texto_sem_pontuacao.split()

frequencia_palavras = {}
for palavra in palavras:
    if palavra not in frequencia_palavras:
        frequencia_palavras[palavra] = 0

    frequencia_palavras[palavra] += 1

frequencia_palavras = Counter(palavras)


frequencia_palavras.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0a2a34d92979> in <cell line: 30>()
#      28
#      29
# ---> 30 frequencia_palavras.head()
#
# AttributeError: 'Counter' object has no attribute 'head'
